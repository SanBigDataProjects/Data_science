# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data= pd.read_csv("train.csv")

# %%
data.head(10)
# Out:
#    User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0  1000001  P00069042      F   0-17          10             A
# 1  1000001  P00248942      F   0-17          10             A
# 2  1000001  P00087842      F   0-17          10             A
# 3  1000001  P00085442      F   0-17          10             A
# 4  1000002  P00285442      M    55+          16             C
# 5  1000003  P00193542      M  26-35          15             A
# 6  1000004  P00184942      M  46-50           7             B
# 7  1000004  P00346142      M  46-50           7             B
# 8  1000004   P0097242      M  46-50           7             B
# 9  1000005  P00274942      M  26-35          20             A
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# ...

# %%
data.shape
# Out:
# (233599, 11)

# %% [markdown]
# Problem Statement
# A retail company “ABC Private Limited” wants to understand the customer purchase behaviour (specifically, purchase amount) against various products of different categories. They have shared purchase summary of various customers for selected high volume products from last month. The data set also contains customer demographics (age, gender, marital status, city_type, stay_in_current_city), product details (product_id and product category) and Total purchase_amount from last month.
#
# Now, they want to build a model to predict the purchase amount of customer against various products which will help them to create personalized offer for customers against different products.

# %%
data_1= pd.read_csv("EdA_new.csv")

# %%
data_1.head()
# Out:
#    User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0  1000004  P00128942      M  46-50           7             B
# 1  1000009  P00113442      M  26-35          17             C
# 2  1000010  P00288442      F  36-45           1             B
# 3  1000010  P00145342      F  36-45           1             B
# 4  1000011  P00053842      F  26-35           1             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               1                   1
# 1                          0               0                   3
# 2                         4+               1                   5
# 3                         4+               1                   4
# 4                          1               0                   4
#
#    Product_Category_2  Product_Category_3
# 0                11.0                 NaN
# 1                 5.0                 NaN
# 2                14.0                 NaN
# ...

# %%
merge_data = pd.merge(data, data_1, on='Product_ID', how='inner')

merge_data
# Out:
#         User_ID_x Product_ID Gender_x  Age_x  Occupation_x City_Category_x  \
# 0         1000003  P00193542        M  26-35            15               A
# 1         1000003  P00193542        M  26-35            15               A
# 2         1000004  P00184942        M  46-50             7               B
# 3         1000004  P00184942        M  46-50             7               B
# 4         1000004  P00184942        M  46-50             7               B
# ...           ...        ...      ...    ...           ...             ...
# 231218    1006040  P00331042        M  26-35             6               B
# 231219    1006040  P00331042        M  26-35             6               B
# 231220    1006040  P00101942        M  26-35             6               B
# 231221    1006040  P00029842        M  26-35             6               B
# 231222    1006040  P00106042        M  26-35             6               B
#
# ...

# %%
merge_data.drop("User_ID_x", axis=1,inplace=True)

# %%
merge_data.describe()
# Out:
#         Occupation_x  Marital_Status_x  Product_Category_1_x  \
# count  231223.000000     231223.000000         231223.000000
# mean        8.164331          0.404389              4.251342
# std         6.448072          0.490774              3.463833
# min         0.000000          0.000000              1.000000
# 25%         3.000000          0.000000              1.000000
# 50%         7.000000          0.000000              5.000000
# 75%        14.000000          1.000000              6.000000
# max        20.000000          1.000000             18.000000
#
#        Product_Category_2_x  Product_Category_3_x       Purchase  \
# count         189483.000000         108239.000000  231223.000000
# mean               8.851691             12.322111   10861.098083
# std                5.451949              4.284565    5190.491701
# min                2.000000              3.000000     185.000000
# 25%                4.000000              8.000000    7032.500000
# ...

# %%
pd.get_dummies(merge_data['Gender_y'])
# Out:
#             F      M
# 0       False   True
# 1       False   True
# 2       False   True
# 3        True  False
# 4        True  False
# ...       ...    ...
# 231218  False   True
# 231219  False   True
# 231220   True  False
# 231221  False   True
# 231222   True  False
#
# [231223 rows x 2 columns]

# %%
merge_data['Gender_x']=merge_data['Gender_x'].map({"F":0,"M":1})

# %%
merge_data.head(20)
# Out:
#    Product_ID  Gender_x  Age_x  Occupation_x City_Category_x  \
# 0   P00193542       NaN  26-35            15               A
# 1   P00193542       NaN  26-35            15               A
# 2   P00184942       NaN  46-50             7               B
# 3   P00184942       NaN  46-50             7               B
# 4   P00184942       NaN  46-50             7               B
# 5   P00346142       NaN  46-50             7               B
# 6   P00346142       NaN  46-50             7               B
# 7   P00014542       NaN  26-35            20               A
# 8   P00145042       NaN  26-35            20               A
# 9   P00145042       NaN  26-35            20               A
# 10   P0096642       NaN  51-55             9               A
# 11  P00058442       NaN  51-55             9               A
# 12  P00220442       NaN  26-35            12               C
# 13  P00156442       NaN  26-35            12               C
# ...

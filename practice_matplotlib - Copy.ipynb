# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
arr_float=np.arange(0,5,1)
arr_float
arr_float1=arr_float*2

# %%
plt.plot(arr_float, arr_float1)
plt.xlabel('x-axis data')
plt.ylabel('y-axis data')
plt.title('Title')
# Out:
# Text(0.5, 1.0, 'Title')

# %%
plt.plot(arr_float, arr_float1,color='r',linestyle='-.',linewidth=1)

# %%
plt.subplot(1,2,1)
plt.plot([2,4,6,8,10])

plt.subplot(1,2,2)
plt.plot([2,4,6,8,10],color='r')

# %%
plt.subplot(3,3,1)
plt.plot([0,1,2,3,4],color='brown')

plt.subplot(3,3,2)
plt.plot([0,1,2,3,4],color='yellow')

plt.subplot(3,3,3)
plt.plot([0,1,2,3,4],color='red')

plt.subplot(3,3,4)
plt.plot([0,1,2,3,4],color='brown')

plt.subplot(3,3,5)
plt.plot([0,1,2,3,4],color='yellow')

plt.subplot(3,3,6)
plt.plot([0,1,2,3,4],color='red')

plt.subplot(3,3,7)
plt.plot([0,1,2,3,4],color='brown')

plt.subplot(3,3,8)
plt.plot([0,1,2,3,4],color='yellow')

plt.subplot(3,3,9)
plt.plot([0,1,2,3,4],color='red')

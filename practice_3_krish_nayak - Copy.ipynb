# %% [markdown]
# Measure Of central Tendency
# Mean
# Median
# Mode

# %%
import numpy as np
import pandas as pd
from scipy import stats
import statistics
import seaborn as sns

# %%
age=[23,24,32,45,12,43,67,45,32,56,32,120]
mean= np.mean(age)
median= np.median(age)
mode= stats.mode(age)
#mean
#median

# %%
#mean1= sum(age)/(len(age))
#mean1
df=pd.DataFrame({'age':age})
df.head()
# Out:
#    age
# 0   23
# 1   24
# 2   32
# 3   45
# 4   12

# %% [markdown]
# #we can also import statistics and use statistics.mean, same like statistics.median , statistics.mode! basically we use mode when we do categorical behavior

# %%
import seaborn as sns

# %%
sns.boxplot(x='age',data=df)
# Out:
# <Axes: xlabel='age'>

# %% [markdown]
# Five Number Summary

# %%
mean= np.mean(df)
max=np.max(df)

# %%
q1,q3 = np.percentile(age, [25,75])
q1,q3
# Out:
# (30.0, 47.75)

# %%
#find outlier[lower_fence-higher fence]
IQR= q3-q1
lower_fence=q1-1.5*(IQR)
higher_fence=q3-1.5*(IQR)
IQR,lower_fence,higher_fence
# Out:
# (17.75, 3.375, 21.125)

# %%
variance1=[(x - mean)**2 for x in df['age']]
variance= np.sum(variance1)/(len(df['age']))
variance
# Out:
# 729.0208333333334

# %%
statistics.variance(age)
# Out:
# 795.2954545454545

# %%
np.var(df['age'])
# Out:
# 729.0208333333334

# %%
sns.histplot(age,kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
df=sns.load_dataset('iris')

# %%
sns.histplot(df['sepal_length'],kde=True)
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
sns.histplot(df['sepal_width'],kde=True)
# Out:
# <Axes: xlabel='sepal_width', ylabel='Count'>

# %%
sns.histplot(df['petal_length'],kde=True)
# Out:
# <Axes: xlabel='petal_length', ylabel='Count'>

# %%
sns.histplot(df['petal_width'],kde=True)
# Out:
# <Axes: xlabel='petal_width', ylabel='Count'>

# %%
sns.histplot(np.random.normal(10,20,1000),kde=True)
# Out:
# <Axes: ylabel='Count'>

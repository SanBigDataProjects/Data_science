# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import seaborn as sns

# %%
data_loc = "https://raw.githubusercontent.com/SanBigDataProjects/Data_science/main/data.csv"
df = pd.read_csv(data_loc)
print(df.head())
# Out:
#    feature1  feature2  feature3     target
# 0 -0.570563  1.420342  0.495580  -9.763182
# 1 -0.990563  0.556965  1.045064 -24.029355
# 2 -0.674728  0.150617  1.774645  45.616421
# 3  0.388250 -0.387127 -0.110229  34.135737
# 4  1.167882 -0.024104  0.145063  86.663647

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,3,1)
plt.scatter(df["feature1"],df["target"],color="red")
plt.xlabel("feature1")
plt.ylabel("target")
plt.title("feature1 vs tatget")


plt.subplot(1,3,2)
plt.scatter(df["feature2"],df["target"],color="red")
plt.xlabel("feature2")
plt.ylabel("target")
plt.title("feature2 vs tatget")

plt.subplot(1,3,3)
plt.scatter(df["feature3"],df["target"],color="red")
plt.xlabel("feature3")
plt.ylabel("target")
plt.title("feature3 vs tatget")
# Out:
# Text(0.5, 1.0, 'feature3 vs tatget')

# %%
x=df.iloc[:,0:3]
y=df.iloc[:,-1]
# Out:
#      feature1  feature2  feature3
# 0   -0.570563  1.420342  0.495580
# 1   -0.990563  0.556965  1.045064
# 2   -0.674728  0.150617  1.774645
# 3    0.388250 -0.387127 -0.110229
# 4    1.167882 -0.024104  0.145063
# ..        ...       ...       ...
# 195  0.255081 -0.231497 -0.239632
# 196  0.276068 -0.648411 -0.077441
# 197  0.122250 -1.157383  0.765721
# 198 -0.914822 -0.897140 -0.784205
# 199  0.090717 -2.217418 -0.892406
#
# [200 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)
residual= y_test - y_pred
#residual

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = []

for i in range(x_train.shape[1]):
    vif.append(variance_inflation_factor(x_train, i))

# %%
pd.DataFrame({'vif': vif}, index=df.columns[0:3]).T
# Out:
#      feature1  feature2  feature3
# vif  1.007179  1.016725  1.019546

# %%
# Another Technique
sns.heatmap(df.iloc[:,0:3].corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.displot(residual,kind='kde')

# %%
# QQ Plot

import scipy as sp

fig, ax = plt.subplots(figsize=(6,4))
sp.stats.probplot(residual, plot=ax, fit=True)

plt.show()

# %%
plt.scatter(y_pred,residual)

# %%
plt.plot(residual)
